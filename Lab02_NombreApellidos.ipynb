# %% [markdown]
# <a href="https://colab.research.google.com/github/mikesaso13/prueba_progra_2_2026/blob/main/Lab02_NombreApellidos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 02: Estructuras de datos, NumPy y Pandas
# ## Caso: análisis de entregas de una plataforma de comercio electrónico
#
# **Universidad de Costa Rica — Escuela de Estadística**
#
# **Curso:** XS-0130 Programación para Estadística II
#
# **Profesor:** Michael Sánchez Soto
#
# **Valor:** 5%
#
# **Puntaje total:** 100 puntos
#
# **Tiempo máximo:** 1 hora y 20 minutos
#
# **Estudiante:** **SU NOMBRE**
#
#
# ### Distribución del puntaje
#
# | Apartado | Puntaje |
# |---|---:|
# | 1. Estructuras de datos y funciones | 15 pts |
# | 2. NumPy | 20 pts |
# | 3. Pandas: creación, exploración y valores faltantes | 20 pts |
# | 4. Pandas: filtros, transformación y ordenamiento | 27 pts |
# | 5. Agrupación y archivo CSV | 18 pts |
# | **Total** | **100 pts** |
#
# ### Objetivo
# Aplicar estructuras de datos nativas, funciones, NumPy y Pandas para organizar, transformar y resumir datos simulados de entregas realizadas por una plataforma de comercio electrónico.
#
# ### Indicaciones
# - Realice el laboratorio en Google Colab.
# - Para esta evaluación **no se permite el uso de herramientas de IA generativa**. Desactive la asistencia con IA de Google Colab antes de iniciar.
# - Resuelva cada apartado utilizando únicamente los contenidos estudiados en clase.
# - Ejecute las celdas en orden y **no modifique la celda de datos base**.
# - Cuando se indique trabajar con NumPy o Pandas, utilice las operaciones propias de esas librerías.
# - Muestre claramente los resultados solicitados.
# - Entregue el archivo `.ipynb` con la notación `Lab02_NombreApellidos.ipynb`.

# %% [markdown]
# ## Contexto del caso
#
# Una plataforma de comercio electrónico desea analizar una muestra de sus entregas recientes.
#
# Para cada pedido se conoce:
#
# - `pedido_id`: identificador del pedido.
# - `zona`: zona general donde se realizó la entrega.
# - `modalidad`: tipo de servicio contratado.
# - `distancia_km`: distancia recorrida para completar la entrega.
# - `tiempo_min`: tiempo total de entrega en minutos.
# - `costo_envio`: costo cobrado por el envío en colones.
# - `calificacion`: calificación otorgada por la persona usuaria, en una escala de 1 a 5.
#
# Algunos registros presentan valores faltantes en `distancia_km`, por lo que será necesario realizar una limpieza básica antes de ciertos análisis.

# %% [markdown]
# ## Datos
#
# Ejecute la siguiente celda antes de resolver los ejercicios. **No modifique estos datos.**

# %%
registros = [
    {"pedido_id": 1,  "zona": "Centro", "modalidad": "Express",  "distancia_km": 3.2,  "tiempo_min": 28, "costo_envio": 2400, "calificacion": 5},
    {"pedido_id": 2,  "zona": "Oeste",  "modalidad": "Estándar", "distancia_km": 7.5,  "tiempo_min": 52, "costo_envio": 3200, "calificacion": 4},
    {"pedido_id": 3,  "zona": "Este",   "modalidad": "Express",  "distancia_km": 4.1,  "tiempo_min": 35, "costo_envio": 2600, "calificacion": 5},
    {"pedido_id": 4,  "zona": "Centro", "modalidad": "Estándar", "distancia_km": None, "tiempo_min": 47, "costo_envio": 2800, "calificacion": 4},
    {"pedido_id": 5,  "zona": "Norte",  "modalidad": "Express",  "distancia_km": 8.3,  "tiempo_min": 49, "costo_envio": 3500, "calificacion": 3},
    {"pedido_id": 6,  "zona": "Oeste",  "modalidad": "Express",  "distancia_km": 5.6,  "tiempo_min": 41, "costo_envio": 3000, "calificacion": 4},
    {"pedido_id": 7,  "zona": "Este",   "modalidad": "Estándar", "distancia_km": 6.8,  "tiempo_min": 55, "costo_envio": 3100, "calificacion": 3},
    {"pedido_id": 8,  "zona": "Centro", "modalidad": "Express",  "distancia_km": 2.7,  "tiempo_min": 24, "costo_envio": 2200, "calificacion": 5},
    {"pedido_id": 9,  "zona": "Norte",  "modalidad": "Estándar", "distancia_km": 9.4,  "tiempo_min": 63, "costo_envio": 3800, "calificacion": 3},
    {"pedido_id": 10, "zona": "Oeste",  "modalidad": "Estándar", "distancia_km": None, "tiempo_min": 50, "costo_envio": 3300, "calificacion": 4},
    {"pedido_id": 11, "zona": "Este",   "modalidad": "Express",  "distancia_km": 3.9,  "tiempo_min": 31, "costo_envio": 2500, "calificacion": 5},
    {"pedido_id": 12, "zona": "Centro", "modalidad": "Estándar", "distancia_km": 5.2,  "tiempo_min": 44, "costo_envio": 2900, "calificacion": 4},
    {"pedido_id": 13, "zona": "Norte",  "modalidad": "Express",  "distancia_km": 7.1,  "tiempo_min": 46, "costo_envio": 3400, "calificacion": 4},
    {"pedido_id": 14, "zona": "Oeste",  "modalidad": "Express",  "distancia_km": 4.8,  "tiempo_min": 38, "costo_envio": 2750, "calificacion": 5}
]

print("Registros cargados:", len(registros))
# Out:
# Registros cargados: 14

# %% [markdown]
# ## 1. Estructuras de datos y funciones — 15 pts
#
# Resuelva los siguientes ejercicios:
#
# **a) [1 pt]** Importe `numpy` con el alias `np` y `pandas` con el alias `pd`.
#
# **b) [2 pts]** Muestre:
#
# - el tipo de `registros`;
# - la cantidad de registros;
# - el primer registro completo.
#
# **c) [3 pts]** Construya un **conjunto** llamado `zonas` que contenga las zonas únicas presentes en los datos. Muéstrelo.
#
# **d) [5 pts]** Defina una función llamada `clasificar_entrega(tiempo, limite=45)` que:
#
# - retorne `"Puntual"` si el tiempo es menor o igual al límite;
# - retorne `"Demorada"` en caso contrario.
#
# **e) [4 pts]** Recorra `registros` y construya una lista llamada `estados_entrega` con la clasificación de cada pedido utilizando la función anterior. Muestre la lista.

# %%
# Escriba su solución aquí

import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. NumPy — 20 pts
#
# A partir de los tiempos de entrega almacenados en `registros`:
#
# **a) [3 pts]** Construya un arreglo NumPy llamado `tiempos`.
#
# **b) [2 pts]** Muestre:
#
# - el arreglo;
# - su `shape`;
# - su `size`.
#
# **c) [4 pts]** Calcule y muestre:
#
# - promedio;
# - mediana;
# - tiempo máximo.
#
# **d) [4 pts]** Sin utilizar ciclos, obtenga en un nuevo arreglo los tiempos de entrega **menores o iguales a 45 minutos**.
#
# **e) [3 pts]** Cree un arreglo llamado `tiempos_escenario` que represente un escenario donde **todos los pedidos tardan 5 minutos adicionales**.
#
# **f) [4 pts]** Indique cuántos pedidos tardaron más de 45 minutos.

# %%
# Escriba su solución aquí

print(registros)
# Out:
# [{'pedido_id': 1, 'zona': 'Centro', 'modalidad': 'Express', 'distancia_km': 3.2, 'tiempo_min': 28, 'costo_envio': 2400, 'calificacion': 5}, {'pedido_id': 2, 'zona': 'Oeste', 'modalidad': 'Estándar', 'distancia_km': 7.5, 'tiempo_min': 52, 'costo_envio': 3200, 'calificacion': 4}, {'pedido_id': 3, 'zona': 'Este', 'modalidad': 'Express', 'distancia_km': 4.1, 'tiempo_min': 35, 'costo_envio': 2600, 'calificacion': 5}, {'pedido_id': 4, 'zona': 'Centro', 'modalidad': 'Estándar', 'distancia_km': None, 'tiempo_min': 47, 'costo_envio': 2800, 'calificacion': 4}, {'pedido_id': 5, 'zona': 'Norte', 'modalidad': 'Express', 'distancia_km': 8.3, 'tiempo_min': 49, 'costo_envio': 3500, 'calificacion': 3}, {'pedido_id': 6, 'zona': 'Oeste', 'modalidad': 'Express', 'distancia_km': 5.6, 'tiempo_min': 41, 'costo_envio': 3000, 'calificacion': 4}, {'pedido_id': 7, 'zona': 'Este', 'modalidad': 'Estándar', 'distancia_km': 6.8, 'tiempo_min': 55, 'costo_envio': 3100, 'calificacion': 3}, {'pedido_id': 8, 'zona': 'C
# ...

# %% [markdown]
# ## 3. Pandas: creación, exploración y valores faltantes — 20 pts
#
# Trabaje ahora con Pandas.
#
# **a) [2 pts]** Cree un DataFrame llamado `df` a partir de `registros`.
#
# **b) [2 pts]** Muestre:
#
# - las primeras cinco filas;
# - las dimensiones del DataFrame utilizando `shape`.
#
# **c) [4 pts]** Identifique cuántos valores faltantes existen en cada columna.
#
# **d) [2 pts]** Cree `df_limpio` como una copia de `df`.
#
# **e) [7 pts]** En `df_limpio`, reemplace los valores faltantes de `distancia_km` con la **mediana** de esa columna.
#
# **f) [3 pts]** Compruebe que `distancia_km` ya no tenga valores faltantes.

# %%
# Escriba su solución aquí

# %% [markdown]
# ## 4. Pandas: filtros, transformación y ordenamiento — 27 pts
#
# Utilice `df_limpio` para resolver:
#
# **a) [5 pts]** Obtenga los pedidos de modalidad `"Express"` cuyo tiempo de entrega sea **menor o igual a 45 minutos**.
#
# **b) [6 pts]** Obtenga los pedidos de las zonas `"Centro"` o `"Este"` cuyo `costo_envio` sea **menor a 3000 colones**.
#
# **c) [5 pts]** Cree una nueva columna llamada `estado` utilizando `np.where()`:
#
# - `"Puntual"` si `tiempo_min <= 45`;
# - `"Demorada"` en caso contrario.
#
# **d) [4 pts]** Cree una nueva columna llamada `costo_por_km` calculada como:
#
# `costo_envio / distancia_km`
#
# **e) [3 pts]** Muestre las primeras cinco filas con las columnas:
#
# `pedido_id`, `zona`, `tiempo_min`, `estado` y `costo_por_km`.
#
# **f) [4 pts]** Ordene los pedidos de menor a mayor según `tiempo_min` y muestre únicamente los cinco primeros.

# %%
# Escriba su solución aquí

# %% [markdown]
# ## 5. Agrupación y archivo CSV — 18 pts
#
# Para finalizar:
#
# **a) [10 pts]** Construya una tabla llamada `resumen_zona` agrupando `df_limpio` por `zona` e incluyendo:
#
# - promedio de `tiempo_min`;
# - promedio de `costo_envio`;
# - cantidad de pedidos.
#
# Muestre el resultado.
#
# **b) [3 pts]** Exporte `df_limpio` a un archivo llamado `entregas_limpias.csv` **sin guardar el índice**.
#
# **c) [2 pts]** Lea nuevamente ese archivo en un DataFrame llamado `df_releido`.
#
# **d) [3 pts]** Muestre las primeras filas de `df_releido` y compruebe que sus dimensiones coincidan con las de `df_limpio`.

# %%
# Escriba su solución aquí

# %% [markdown]
# ## Entrega
#
# Antes de entregar:
#
# - Verifique que todas las celdas de código se ejecuten sin errores. Recuerden que si algo "no corre" no se obtienen puntos aunque parte de la lógica sea correcta.
# - Compruebe que los resultados estén claramente identificados.
# - Ejecute el notebook desde el inicio para verificar que no dependa de ejecuciones previas.
# - Guarde y entregue únicamente su archivo `.ipynb`.
